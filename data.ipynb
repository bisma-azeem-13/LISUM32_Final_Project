# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Veri setini yükleme
df = pd.read_csv('bank-additional-full.csv', delimiter=';')

# Eksik değerlerin kontrol edilmesi
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Series([], dtype: int64)

# %%
# 'unknown' değerlerinin sayısını hesaplama
unknown_counts = df.apply(lambda x: (x == 'unknown').sum())
unknown_counts = unknown_counts[unknown_counts > 0]
print("Number of 'unknown' values in each column:\n", unknown_counts)
# Out:
# Number of 'unknown' values in each column:
#  job           330
# marital        80
# education    1731
# default      8597
# housing       990
# loan          990
# dtype: int64

# %%
# Sayısal sütunların seçilmesi
numeric_columns = df.select_dtypes(include=[np.number]).columns

# Her bir sayısal sütun için aykırı değerlerin görselleştirilmesi
for col in numeric_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
# Her bir sayısal sütun için histogram ve KDE
for col in numeric_columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
# Kategorik sütunların seçilmesi
categorical_columns = df.select_dtypes(include=['object']).columns

# Her bir kategorik sütun için sütun grafiği
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=45)
    plt.show()
